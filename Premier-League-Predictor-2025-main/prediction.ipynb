# %%
import pandas as pd

# %%
matches = pd.read_csv("D:\coding\lol api\matches.csv", index_col=0)
matches.head()
# Out:
#          date   time            comp        round  day venue result  gf  ga  \
# 0  17/08/2024  12:30  Premier League  Matchweek 1  Sat  Away      W   2   0
# 1  25/08/2024  16:30  Premier League  Matchweek 2  Sun  Home      W   2   0
# 2  01/09/2024  16:00  Premier League  Matchweek 3  Sun  Away      W   3   0
# 3  14/09/2024  15:00  Premier League  Matchweek 4  Sat  Home      L   0   1
# 5  21/09/2024  15:00  Premier League  Matchweek 5  Sat  Home      W   3   0
#
#           opponent  ...  match report  notes  sh  sot  dist fk pk pkatt  \
# 0     Ipswich Town  ...  Match Report    NaN  18    5  14.8  0  0     0
# 1        Brentford  ...  Match Report    NaN  19    8  13.6  1  0     0
# 2   Manchester Utd  ...  Match Report    NaN  11    3  13.4  0  0     0
# 3  Nott'ham Forest  ...  Match Report    NaN  14    5  14.9  0  0     0
# 5      Bournemouth  ...  Match Report    NaN  19   12  16.6  0  0     0
#
#   season       team
# 0   2025  Liverpool
# 1   2025  Liverpool
# 2   2025  Liverpool
# 3   2025  Liverpool
# 5   2025  Liverpool
#
# [5 rows x 28 columns]

# %%
matches.shape
# Out:
# (856, 28)

# %% [markdown]
# INVESTIGATING MISSING DATA

# %%
matches["team"].value_counts()
# Out:
# team
# Arsenal                     134
# Liverpool                   133
# Manchester City             114
# Aston Villa                  76
# Chelsea                      76
# Tottenham Hotspur            76
# Manchester United            76
# Newcastle United             38
# West Ham United              38
# Brighton and Hove Albion     38
# Leicester City               38
# Nottingham Forest            19
# Name: count, dtype: int64

# %%
matches[matches["team"] == "Chelsea"].sort_values("date")
# Out:
#           date   time            comp         round  day venue result  gf  ga  \
# 55  01/05/2022  14:00  Premier League  Matchweek 35  Sun  Away      L   0   1
# 21  01/12/2021  19:30  Premier League  Matchweek 14  Wed  Away      W   2   1
# 30  02/01/2022  16:30  Premier League  Matchweek 21  Sun  Home      D   2   2
# 36  02/03/2024  15:00  Premier League  Matchweek 27  Sat  Away      D   2   2
# 47  02/04/2022  15:00  Premier League  Matchweek 31  Sat  Home      L   1   4
# ..         ...    ...             ...           ...  ...   ...    ...  ..  ..
# 29  29/12/2021  19:30  Premier League  Matchweek 20  Wed  Home      D   1   1
# 39  30/03/2024  15:00  Premier League  Matchweek 30  Sat  Home      D   2   2
# 15  30/10/2021  15:00  Premier League  Matchweek 10  Sat  Away      W   3   0
# 23  30/12/2023  12:30  Premier League  Matchweek 20  Sat  Away      W   3   2
# 29  31/01/2024  20:15  Premier League  Matchweek 22  Wed  Away      L   1   4
#
#          opponent  ...  match report  notes  sh  sot  dist fk pk pkatt season  \
# 55        Everton  ...  Match Report    NaN  17    5  17.9  0  0     0   2025
# 21        Watford  ...  Match Report    NaN   8    4  15.1  0  0     0   2025
# 30      Liverpool  ...  Match Report    NaN  15    6  18.0  3  0     0   2025
# 36      Brentford  ...  Match Report    NaN  17    5  19.5  0  0     0   2025
# 47      Brentford  ...  Match Report    NaN  21    8  20.1  0  0     0   2025
# ..            ...  ...           ...    ...  ..  ...   ... .. ..   ...    ...
# 29       Brighton  ...  Match Report    NaN  11    5  13.6  0  0     0   2025
# 39        Burnley  ...  Match Report    NaN  32   12  17.8  0  1     1   2025
# 15  Newcastle Utd  ...  Match Report    NaN  18    5  20.5  1  1     1   2025
# 23     Luton Town  ...  Match Report    NaN  12    8  17.5  0  0     0   2025
# 29      Liverpool  ...  Match Report    NaN   4    3  18.8  0  0     0   2025
#
#        team
# 55  Chelsea
# 21  Chelsea
# 30  Chelsea
# 36  Chelsea
# 47  Chelsea
# ..      ...
# 29  Chelsea
# 39  Chelsea
# 15  Chelsea
# 23  Chelsea
# 29  Chelsea
#
# [76 rows x 28 columns]

# %%
matches["round"].value_counts()
# Out:
# round
# Matchweek 1     24
# Matchweek 2     24
# Matchweek 3     24
# Matchweek 4     24
# Matchweek 5     24
# Matchweek 6     24
# Matchweek 7     24
# Matchweek 8     24
# Matchweek 9     24
# Matchweek 10    24
# Matchweek 11    24
# Matchweek 12    24
# Matchweek 13    24
# Matchweek 14    24
# Matchweek 16    24
# Matchweek 17    24
# Matchweek 18    24
# Matchweek 19    24
# Matchweek 20    23
# Matchweek 15    23
# Matchweek 21    21
# Matchweek 22    21
# Matchweek 23    21
# Matchweek 24    21
# Matchweek 25    21
# Matchweek 26    21
# Matchweek 27    21
# Matchweek 28    21
# Matchweek 30    21
# Matchweek 31    21
# Matchweek 32    21
# Matchweek 33    21
# Matchweek 29    21
# Matchweek 35    21
# Matchweek 36    21
# Matchweek 37    21
# Matchweek 34    21
# Matchweek 38    21
# Name: count, dtype: int64

# %% [markdown]
# CLEANING THE DATA FOR MACHINE LEARNING

# %%
matches.dtypes
# Out:
# date              object
# time              object
# comp              object
# round             object
# day               object
# venue             object
# result            object
# gf                 int64
# ga                 int64
# opponent          object
# xg               float64
# xga              float64
# poss               int64
# attendance       float64
# captain           object
# formation         object
# opp formation     object
# referee           object
# match report      object
# notes            float64
# sh                 int64
# sot                int64
# dist             float64
# fk                 int64
# pk                 int64
# pkatt              int64
# season             int64
# team              object
# dtype: object

# %%
del matches["comp"]

# %%
del matches["notes"]

# %%
matches["date"] = pd.to_datetime(matches["date"])
# Out:
# C:\Users\France\AppData\Local\Temp\ipykernel_12564\2174778740.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   matches["date"] = pd.to_datetime(matches["date"])

# %%
matches
# Out:
#          date   time         round  day venue result  gf  ga         opponent  \
# 0  2024-08-17  12:30   Matchweek 1  Sat  Away      W   2   0     Ipswich Town
# 1  2024-08-25  16:30   Matchweek 2  Sun  Home      W   2   0        Brentford
# 2  2024-09-01  16:00   Matchweek 3  Sun  Away      W   3   0   Manchester Utd
# 3  2024-09-14  15:00   Matchweek 4  Sat  Home      L   0   1  Nott'ham Forest
# 5  2024-09-21  15:00   Matchweek 5  Sat  Home      W   3   0      Bournemouth
# ..        ...    ...           ...  ...   ...    ...  ..  ..              ...
# 53 2022-05-08  14:00  Matchweek 36  Sun  Home      L   1   2          Everton
# 54 2022-05-11  19:45  Matchweek 21  Wed  Home      W   3   0     Norwich City
# 55 2022-05-15  14:00  Matchweek 37  Sun  Away      W   5   1          Watford
# 56 2022-05-19  20:00  Matchweek 27  Thu  Away      D   1   1          Chelsea
# 57 2022-05-22  16:00  Matchweek 38  Sun  Home      W   4   1      Southampton
#
#      xg  ...  match report  sh  sot  dist fk pk pkatt season            team  \
# 0   2.6  ...  Match Report  18    5  14.8  0  0     0   2025       Liverpool
# 1   2.5  ...  Match Report  19    8  13.6  1  0     0   2025       Liverpool
# 2   1.8  ...  Match Report  11    3  13.4  0  0     0   2025       Liverpool
# 3   0.9  ...  Match Report  14    5  14.9  0  0     0   2025       Liverpool
# 5   2.0  ...  Match Report  19   12  16.6  0  0     0   2025       Liverpool
# ..  ...  ...           ...  ..  ...   ... .. ..   ...    ...             ...
# 53  1.5  ...  Match Report  16    8  19.8  0  0     0   2025  Leicester City
# 54  2.0  ...  Match Report  20    8  18.5  0  0     0   2025  Leicester City
# 55  2.5  ...  Match Report  13    7  16.4  0  0     0   2025  Leicester City
# 56  0.1  ...  Match Report   2    1  25.1  0  0     0   2025  Leicester City
# 57  3.4  ...  Match Report  12    6  12.8  0  0     0   2025  Leicester City
#
#     target
# 0        1
# 1        1
# 2        1
# 3        0
# 5        1
# ..     ...
# 53       0
# 54       1
# 55       1
# 56       0
# 57       1
#
# [856 rows x 27 columns]

# %%
matches.dtypes
# Out:
# date             datetime64[ns]
# time                     object
# round                    object
# day                      object
# venue                    object
# result                   object
# gf                        int64
# ga                        int64
# opponent                 object
# xg                      float64
# xga                     float64
# poss                      int64
# attendance              float64
# captain                  object
# formation                object
# opp formation            object
# referee                  object
# match report             object
# sh                        int64
# sot                       int64
# dist                    float64
# fk                        int64
# pk                        int64
# pkatt                     int64
# season                    int64
# team                     object
# target                    int64
# dtype: object

# %% [markdown]
# CREATING PREDICTORS FOR MACHINE LEARNING

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches["hour"] = matches["time"].str.replace(":.+","", regex=True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches["target"] = (matches["result"] == "W").astype("int")

# %%
matches
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 0  2024-08-17  12:30  Premier League   Matchweek 1  Sat  Away      W   2   0
# 1  2024-08-25  16:30  Premier League   Matchweek 2  Sun  Home      W   2   0
# 2  2024-09-01  16:00  Premier League   Matchweek 3  Sun  Away      W   3   0
# 3  2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      L   0   1
# 5  2024-09-21  15:00  Premier League   Matchweek 5  Sat  Home      W   3   0
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 53 2022-05-08  14:00  Premier League  Matchweek 36  Sun  Home      L   1   2
# 54 2022-05-11  19:45  Premier League  Matchweek 21  Wed  Home      W   3   0
# 55 2022-05-15  14:00  Premier League  Matchweek 37  Sun  Away      W   5   1
# 56 2022-05-19  20:00  Premier League  Matchweek 27  Thu  Away      D   1   1
# 57 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Home      W   4   1
#
#            opponent  ...  fk  pk  pkatt  season            team venue_code  \
# 0      Ipswich Town  ...   0   0      0    2025       Liverpool          0
# 1         Brentford  ...   1   0      0    2025       Liverpool          1
# 2    Manchester Utd  ...   0   0      0    2025       Liverpool          0
# 3   Nott'ham Forest  ...   0   0      0    2025       Liverpool          1
# 5       Bournemouth  ...   0   0      0    2025       Liverpool          1
# ..              ...  ...  ..  ..    ...     ...             ...        ...
# 53          Everton  ...   0   0      0    2025  Leicester City          1
# 54     Norwich City  ...   0   0      0    2025  Leicester City          1
# 55          Watford  ...   0   0      0    2025  Leicester City          0
# 56          Chelsea  ...   0   0      0    2025  Leicester City          0
# 57      Southampton  ...   0   0      0    2025  Leicester City          1
#
#    opp_code hour day_code  target
# 0        10   12        5       1
# 1         3   16        6       1
# 2        16   16        6       1
# 3        19   15        5       0
# 5         2   15        5       1
# ..      ...  ...      ...     ...
# 53        8   14        6       0
# 54       18   19        2       1
# 55       23   14        6       1
# 56        6   20        3       0
# 57       21   16        6       1
#
# [856 rows x 33 columns]

# %% [markdown]
# CREATING INITIAL MACHINE LEARNING MODEL

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2022-01-01']

# %%
test = matches[matches["date"] > '2022-01-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
error = accuracy_score(test["target"], preds)

# %%
error
# Out:
# 0.5683760683760684

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted    0    1
# actual
# 0          136  161
# 1          142  263

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds)
# Out:
# 0.6202830188679245

# %% [markdown]
# IMPROVING PRECISION WITH ROLLING AVERAGES

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Chelsea")
group
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 0  2023-08-13  16:30  Premier League   Matchweek 1  Sun  Home      D   1   1
# 1  2023-08-20  16:30  Premier League   Matchweek 2  Sun  Away      L   1   3
# 2  2023-08-25  20:00  Premier League   Matchweek 3  Fri  Home      W   3   0
# 4  2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      L   0   1
# 5  2023-09-17  14:00  Premier League   Matchweek 5  Sun  Away      D   0   0
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 55 2022-05-01  14:00  Premier League  Matchweek 35  Sun  Away      L   0   1
# 56 2022-05-07  15:00  Premier League  Matchweek 36  Sat  Home      D   2   2
# 57 2022-05-11  19:30  Premier League  Matchweek 33  Wed  Away      W   3   0
# 59 2022-05-19  20:00  Premier League  Matchweek 27  Thu  Home      D   1   1
# 60 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Home      W   2   1
#
#            opponent  ...  fk  pk  pkatt  season     team venue_code opp_code  \
# 0         Liverpool  ...   1   0      0    2025  Chelsea          1       13
# 1          West Ham  ...   0   0      1    2025  Chelsea          0       24
# 2        Luton Town  ...   1   0      0    2025  Chelsea          1       14
# 4   Nott'ham Forest  ...   2   0      0    2025  Chelsea          1       19
# 5       Bournemouth  ...   1   0      0    2025  Chelsea          0        2
# ..              ...  ...  ..  ..    ...     ...      ...        ...      ...
# 55          Everton  ...   0   0      0    2025  Chelsea          0        8
# 56           Wolves  ...   2   1      1    2025  Chelsea          1       25
# 57     Leeds United  ...   0   0      0    2025  Chelsea          0       11
# 59   Leicester City  ...   2   0      0    2025  Chelsea          1       12
# 60          Watford  ...   0   0      0    2025  Chelsea          1       23
#
#    hour day_code  target
# 0    16        6       0
# 1    16        6       0
# 2    20        4       1
# 4    15        5       0
# 5    14        6       0
# ..  ...      ...     ...
# 55   14        6       0
# 56   15        5       0
# 57   19        2       1
# 59   20        3       0
# 60   16        6       1
#
# [76 rows x 33 columns]

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

rolling_averages(group, cols, new_cols)
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 4  2021-09-11  17:30  Premier League   Matchweek 4  Sat  Home      W   3   0
# 6  2021-09-19  16:30  Premier League   Matchweek 5  Sun  Away      W   3   0
# 8  2021-09-25  12:30  Premier League   Matchweek 6  Sat  Home      L   0   1
# 10 2021-10-02  15:00  Premier League   Matchweek 7  Sat  Home      W   3   1
# 11 2021-10-16  17:30  Premier League   Matchweek 8  Sat  Away      W   1   0
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 46 2024-05-02  19:30  Premier League  Matchweek 26  Thu  Home      W   2   0
# 47 2024-05-05  14:00  Premier League  Matchweek 36  Sun  Home      W   5   0
# 48 2024-05-11  17:30  Premier League  Matchweek 37  Sat  Away      W   3   2
# 49 2024-05-15  19:45  Premier League  Matchweek 34  Wed  Away      W   2   1
# 50 2024-05-19  16:00  Premier League  Matchweek 38  Sun  Home      W   2   1
#
#            opponent  ...  day_code  target  gf_rolling  ga_rolling sh_rolling  \
# 4       Aston Villa  ...         5       1    2.000000    0.333333  13.666667
# 6         Tottenham  ...         6       1    2.000000    0.333333  13.333333
# 8   Manchester City  ...         5       0    2.333333    0.333333  12.666667
# 10      Southampton  ...         5       1    2.000000    0.333333  12.333333
# 11        Brentford  ...         5       1    2.000000    0.666667  15.000000
# ..              ...  ...       ...     ...         ...         ...        ...
# 46        Tottenham  ...         3       1    2.666667    2.333333  13.666667
# 47         West Ham  ...         6       1    1.333333    2.333333  14.666667
# 48  Nott'ham Forest  ...         5       1    3.000000    0.666667  20.666667
# 49         Brighton  ...         2       1    3.333333    0.666667  17.666667
# 50      Bournemouth  ...         6       1    3.333333    1.000000  17.000000
#
#    sot_rolling dist_rolling fk_rolling pk_rolling  pkatt_rolling
# 4     4.666667    16.500000   1.333333   0.000000       0.000000
# 6     4.000000    17.033333   0.000000   0.000000       0.000000
# 8     5.333333    16.533333   0.000000   0.000000       0.000000
# 10    4.333333    21.666667   0.333333   0.000000       0.000000
# 11    6.000000    18.400000   0.333333   0.000000       0.000000
# ..         ...          ...        ...        ...            ...
# 46    5.000000    17.833333   0.666667   0.333333       0.333333
# 47    3.333333    16.933333   1.333333   0.000000       0.000000
# 48    7.666667    17.833333   1.333333   0.000000       0.000000
# 49    7.666667    14.600000   1.333333   0.000000       0.000000
# 50    8.333333    16.000000   1.333333   0.000000       0.000000
#
# [73 rows x 41 columns]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
matches_rolling
# Out:
# C:\Users\France\AppData\Local\Temp\ipykernel_12564\1738758534.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
#                          date   time            comp         round  day venue  \
# team
# Arsenal         4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Home
#                 5  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Away
#                 7  2021-09-26  16:30  Premier League   Matchweek 6  Sun  Home
#                 8  2021-10-02  17:30  Premier League   Matchweek 7  Sat  Away
#                 9  2021-10-18  20:00  Premier League   Matchweek 8  Mon  Home
# ...                       ...    ...             ...           ...  ...   ...
# West Ham United 49 2022-04-24  14:00  Premier League  Matchweek 34  Sun  Away
#                 51 2022-05-01  16:30  Premier League  Matchweek 35  Sun  Home
#                 53 2022-05-08  14:00  Premier League  Matchweek 36  Sun  Away
#                 54 2022-05-15  14:00  Premier League  Matchweek 37  Sun  Home
#                 55 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Away
#
#                    result  gf  ga         opponent  ...  day_code  target  \
# team                                                ...
# Arsenal         4       W   1   0     Norwich City  ...         5       1
#                 5       W   1   0          Burnley  ...         5       1
#                 7       W   3   1        Tottenham  ...         6       1
#                 8       D   0   0         Brighton  ...         5       0
#                 9       D   2   2   Crystal Palace  ...         0       0
# ...                   ...  ..  ..              ...  ...       ...     ...
# West Ham United 49      L   0   1          Chelsea  ...         6       0
#                 51      L   1   2          Arsenal  ...         6       0
#                 53      W   4   0     Norwich City  ...         6       1
#                 54      D   2   2  Manchester City  ...         6       0
#                 55      L   1   3         Brighton  ...         6       0
#
#                     gf_rolling  ga_rolling sh_rolling sot_rolling  \
# team
# Arsenal         4     0.000000    3.000000   9.666667    2.333333
#                 5     0.333333    2.333333  12.333333    3.000000
#                 7     0.666667    1.666667  14.666667    3.000000
#                 8     1.666667    0.333333  18.333333    5.333333
#                 9     1.333333    0.333333  11.000000    4.000000
# ...                        ...         ...        ...         ...
# West Ham United 49    1.000000    1.333333  12.333333    4.000000
#                 51    0.333333    1.333333  10.666667    3.000000
#                 53    0.666667    1.333333  11.666667    3.666667
#                 54    1.666667    1.000000   8.666667    3.000000
#                 55    2.333333    1.333333   8.666667    3.000000
#
#                    dist_rolling fk_rolling pk_rolling  pkatt_rolling
# team
# Arsenal         4     14.833333   0.333333   0.000000       0.000000
#                 5     14.133333   0.333333   0.000000       0.000000
#                 7     14.800000   0.666667   0.000000       0.000000
#                 8     18.433333   0.666667   0.000000       0.000000
#                 9     19.833333   0.666667   0.000000       0.000000
# ...                         ...        ...        ...            ...
# West Ham United 49    17.366667   0.666667   0.000000       0.000000
#                 51    15.200000   0.000000   0.000000       0.000000
#                 53    14.033333   0.000000   0.000000       0.000000
#                 54    13.933333   0.000000   0.333333       0.333333
#                 55    14.033333   0.000000   0.333333       0.333333
#
# [820 rows x 41 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')
matches_rolling
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Home      W   1   0
# 5  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Away      W   1   0
# 7  2021-09-26  16:30  Premier League   Matchweek 6  Sun  Home      W   3   1
# 8  2021-10-02  17:30  Premier League   Matchweek 7  Sat  Away      D   0   0
# 9  2021-10-18  20:00  Premier League   Matchweek 8  Mon  Home      D   2   2
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 49 2022-04-24  14:00  Premier League  Matchweek 34  Sun  Away      L   0   1
# 51 2022-05-01  16:30  Premier League  Matchweek 35  Sun  Home      L   1   2
# 53 2022-05-08  14:00  Premier League  Matchweek 36  Sun  Away      W   4   0
# 54 2022-05-15  14:00  Premier League  Matchweek 37  Sun  Home      D   2   2
# 55 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Away      L   1   3
#
#            opponent  ...  day_code  target  gf_rolling  ga_rolling sh_rolling  \
# 4      Norwich City  ...         5       1    0.000000    3.000000   9.666667
# 5           Burnley  ...         5       1    0.333333    2.333333  12.333333
# 7         Tottenham  ...         6       1    0.666667    1.666667  14.666667
# 8          Brighton  ...         5       0    1.666667    0.333333  18.333333
# 9    Crystal Palace  ...         0       0    1.333333    0.333333  11.000000
# ..              ...  ...       ...     ...         ...         ...        ...
# 49          Chelsea  ...         6       0    1.000000    1.333333  12.333333
# 51          Arsenal  ...         6       0    0.333333    1.333333  10.666667
# 53     Norwich City  ...         6       1    0.666667    1.333333  11.666667
# 54  Manchester City  ...         6       0    1.666667    1.000000   8.666667
# 55         Brighton  ...         6       0    2.333333    1.333333   8.666667
#
#    sot_rolling dist_rolling fk_rolling pk_rolling  pkatt_rolling
# 4     2.333333    14.833333   0.333333   0.000000       0.000000
# 5     3.000000    14.133333   0.333333   0.000000       0.000000
# 7     3.000000    14.800000   0.666667   0.000000       0.000000
# 8     5.333333    18.433333   0.666667   0.000000       0.000000
# 9     4.000000    19.833333   0.666667   0.000000       0.000000
# ..         ...          ...        ...        ...            ...
# 49    4.000000    17.366667   0.666667   0.000000       0.000000
# 51    3.000000    15.200000   0.000000   0.000000       0.000000
# 53    3.666667    14.033333   0.000000   0.000000       0.000000
# 54    3.000000    13.933333   0.000000   0.333333       0.333333
# 55    3.000000    14.033333   0.000000   0.333333       0.333333
#
# [820 rows x 41 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])
matches_rolling
# Out:
#           date   time            comp         round  day venue result  gf  ga  \
# 0   2021-09-11  15:00  Premier League   Matchweek 4  Sat  Home      W   1   0
# 1   2021-09-18  15:00  Premier League   Matchweek 5  Sat  Away      W   1   0
# 2   2021-09-26  16:30  Premier League   Matchweek 6  Sun  Home      W   3   1
# 3   2021-10-02  17:30  Premier League   Matchweek 7  Sat  Away      D   0   0
# 4   2021-10-18  20:00  Premier League   Matchweek 8  Mon  Home      D   2   2
# ..         ...    ...             ...           ...  ...   ...    ...  ..  ..
# 815 2022-04-24  14:00  Premier League  Matchweek 34  Sun  Away      L   0   1
# 816 2022-05-01  16:30  Premier League  Matchweek 35  Sun  Home      L   1   2
# 817 2022-05-08  14:00  Premier League  Matchweek 36  Sun  Away      W   4   0
# 818 2022-05-15  14:00  Premier League  Matchweek 37  Sun  Home      D   2   2
# 819 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Away      L   1   3
#
#             opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# 0       Norwich City  ...         5       1    0.000000    3.000000
# 1            Burnley  ...         5       1    0.333333    2.333333
# 2          Tottenham  ...         6       1    0.666667    1.666667
# 3           Brighton  ...         5       0    1.666667    0.333333
# 4     Crystal Palace  ...         0       0    1.333333    0.333333
# ..               ...  ...       ...     ...         ...         ...
# 815          Chelsea  ...         6       0    1.000000    1.333333
# 816          Arsenal  ...         6       0    0.333333    1.333333
# 817     Norwich City  ...         6       1    0.666667    1.333333
# 818  Manchester City  ...         6       0    1.666667    1.000000
# 819         Brighton  ...         6       0    2.333333    1.333333
#
#     sh_rolling sot_rolling dist_rolling fk_rolling pk_rolling  pkatt_rolling
# 0     9.666667    2.333333    14.833333   0.333333   0.000000       0.000000
# 1    12.333333    3.000000    14.133333   0.333333   0.000000       0.000000
# 2    14.666667    3.000000    14.800000   0.666667   0.000000       0.000000
# 3    18.333333    5.333333    18.433333   0.666667   0.000000       0.000000
# 4    11.000000    4.000000    19.833333   0.666667   0.000000       0.000000
# ..         ...         ...          ...        ...        ...            ...
# 815  12.333333    4.000000    17.366667   0.666667   0.000000       0.000000
# 816  10.666667    3.000000    15.200000   0.000000   0.000000       0.000000
# 817  11.666667    3.666667    14.033333   0.000000   0.000000       0.000000
# 818   8.666667    3.000000    13.933333   0.000000   0.333333       0.333333
# 819   8.666667    3.000000    14.033333   0.000000   0.333333       0.333333
#
# [820 rows x 41 columns]

# %% [markdown]
# RETRAINING THE MACHINE LEARNING MODEL

# %%
def make_predictions(data, predictors):
    train =data[data["date"] < '2022-01-01']
    test = data[data["date"] > '2022-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    precision = precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.5947867298578199

# %%
combined
# Out:
#      actual  predicted
# 17        0          1
# 18        1          1
# 19        1          1
# 20        1          1
# 21        1          1
# ..      ...        ...
# 815       0          0
# 816       0          1
# 817       1          0
# 818       0          0
# 819       0          0
#
# [690 rows x 2 columns]

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined
# Out:
#      actual  predicted     date_x           team_x       opponent_x result_x  \
# 17        0          1 2022-01-23          Arsenal          Burnley        D
# 18        1          1 2022-02-10          Arsenal           Wolves        W
# 19        1          1 2022-02-19          Arsenal        Brentford        W
# 20        1          1 2022-02-24          Arsenal           Wolves        W
# 21        1          1 2022-03-06          Arsenal          Watford        W
# ..      ...        ...        ...              ...              ...      ...
# 815       0          0 2022-04-24  West Ham United          Chelsea        L
# 816       0          1 2022-05-01  West Ham United          Arsenal        L
# 817       1          0 2022-05-08  West Ham United     Norwich City        W
# 818       0          0 2022-05-15  West Ham United  Manchester City        D
# 819       0          0 2022-05-22  West Ham United         Brighton        L
#
#      new_team     date_y           team_y       opponent_y result_y  \
# 17        NaN 2022-01-23          Arsenal          Burnley        D
# 18        NaN 2022-02-10          Arsenal           Wolves        W
# 19        NaN 2022-02-19          Arsenal        Brentford        W
# 20        NaN 2022-02-24          Arsenal           Wolves        W
# 21        NaN 2022-03-06          Arsenal          Watford        W
# ..        ...        ...              ...              ...      ...
# 815  West Ham 2022-04-24  West Ham United          Chelsea        L
# 816  West Ham 2022-05-01  West Ham United          Arsenal        L
# 817  West Ham 2022-05-08  West Ham United     Norwich City        W
# 818  West Ham 2022-05-15  West Ham United  Manchester City        D
# 819  West Ham 2022-05-22  West Ham United         Brighton        L
#
#           date             team         opponent result
# 17  2022-01-23          Arsenal          Burnley      D
# 18  2022-02-10          Arsenal           Wolves      W
# 19  2022-02-19          Arsenal        Brentford      W
# 20  2022-02-24          Arsenal           Wolves      W
# 21  2022-03-06          Arsenal          Watford      W
# ..         ...              ...              ...    ...
# 815 2022-04-24  West Ham United          Chelsea      L
# 816 2022-05-01  West Ham United          Arsenal      L
# 817 2022-05-08  West Ham United     Norwich City      W
# 818 2022-05-15  West Ham United  Manchester City      D
# 819 2022-05-22  West Ham United         Brighton      L
#
# [690 rows x 15 columns]

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [50, 100, 200],
    'min_samples_split': [2, 5, 10],
    'max_depth': [None, 10, 20, 30],
    'random_state': [0, 1, 50]
}

grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5, scoring='precision')
grid_search.fit(train[predictors], train["target"])

best_params = grid_search.best_params_
print(f"Best Parameters: {best_params}")
# Out:
# Best Parameters: {'max_depth': None, 'min_samples_split': 5, 'n_estimators': 200, 'random_state': 50}

# %%
from sklearn.model_selection import cross_val_score

cv_scores = cross_val_score(rf, train[predictors], train["target"], cv=5, scoring='precision')
print(f"Cross-Validation Precision Scores: {cv_scores}")
print(f"Mean Precision Score: {cv_scores.mean()}")
# Out:
# Cross-Validation Precision Scores: [0.5625     0.44444444 0.5        0.7        0.52941176]
# Mean Precision Score: 0.5472712418300654

# %% [markdown]
# COMBINING HOME AND AWAY PREDICTIONS

# %%
class MissingDict(dict):
    __missing_ = lambda self, key: key

map_values = {
    "Brighton and Hove Albbion": "Brighton",
    "Manchester United": "Manchester Utd",
    "Newcaster United": "Newcastle Utd",
    "Totthenham Hotspur": "Tottenham",
    "West Ham United": "West Ham",
    "Wolverhampton Wanderers": "Wolves"
}

mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
combined.head(10)
# Out:
#     actual  predicted     date_x   team_x      opponent_x result_x new_team  \
# 17       0          1 2022-01-23  Arsenal         Burnley        D      NaN
# 18       1          1 2022-02-10  Arsenal          Wolves        W      NaN
# 19       1          1 2022-02-19  Arsenal       Brentford        W      NaN
# 20       1          1 2022-02-24  Arsenal          Wolves        W      NaN
# 21       1          1 2022-03-06  Arsenal         Watford        W      NaN
# 22       1          1 2022-03-13  Arsenal  Leicester City        W      NaN
# 23       0          1 2022-03-16  Arsenal       Liverpool        L      NaN
# 24       1          1 2022-03-19  Arsenal     Aston Villa        W      NaN
# 25       0          0 2022-04-04  Arsenal  Crystal Palace        L      NaN
# 26       0          1 2022-04-09  Arsenal        Brighton        L      NaN
#
#        date_y   team_y      opponent_y result_y       date     team  \
# 17 2022-01-23  Arsenal         Burnley        D 2022-01-23  Arsenal
# 18 2022-02-10  Arsenal          Wolves        W 2022-02-10  Arsenal
# 19 2022-02-19  Arsenal       Brentford        W 2022-02-19  Arsenal
# 20 2022-02-24  Arsenal          Wolves        W 2022-02-24  Arsenal
# 21 2022-03-06  Arsenal         Watford        W 2022-03-06  Arsenal
# 22 2022-03-13  Arsenal  Leicester City        W 2022-03-13  Arsenal
# 23 2022-03-16  Arsenal       Liverpool        L 2022-03-16  Arsenal
# 24 2022-03-19  Arsenal     Aston Villa        W 2022-03-19  Arsenal
# 25 2022-04-04  Arsenal  Crystal Palace        L 2022-04-04  Arsenal
# 26 2022-04-09  Arsenal        Brighton        L 2022-04-09  Arsenal
#
#           opponent result
# 17         Burnley      D
# 18          Wolves      W
# 19       Brentford      W
# 20          Wolves      W
# 21         Watford      W
# 22  Leicester City      W
# 23       Liverpool      L
# 24     Aston Villa      W
# 25  Crystal Palace      L
# 26        Brighton      L

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged
# Out:
#     actual_x  predicted_x   date_x_x           team_x_x     opponent_x_x  \
# 0          1            1 2022-01-22  Manchester United         West Ham
# 1          0            1 2022-03-06  Manchester United  Manchester City
# 2          1            1 2022-03-12  Manchester United        Tottenham
# 3          0            1 2022-04-02  Manchester United   Leicester City
# 4          0            1 2022-04-19  Manchester United        Liverpool
# 5          0            1 2022-04-23  Manchester United          Arsenal
# 6          0            0 2022-04-28  Manchester United          Chelsea
# 7          1            0 2022-08-22  Manchester United        Liverpool
# 8          1            1 2022-09-04  Manchester United          Arsenal
# 9          0            0 2022-10-02  Manchester United  Manchester City
# 10         0            1 2022-10-16  Manchester United    Newcastle Utd
# 11         0            0 2022-11-06  Manchester United      Aston Villa
# 12         1            0 2023-01-14  Manchester United  Manchester City
# 13         0            1 2023-01-22  Manchester United          Arsenal
# 14         0            1 2023-03-05  Manchester United        Liverpool
# 15         0            1 2023-04-02  Manchester United    Newcastle Utd
# 16         1            1 2023-04-30  Manchester United      Aston Villa
# 17         0            1 2023-05-04  Manchester United         Brighton
# 18         0            0 2022-01-22    West Ham United   Manchester Utd
# 19         0            0 2022-02-13    West Ham United   Leicester City
# 20         0            1 2022-03-05    West Ham United        Liverpool
# 21         0            1 2022-03-20    West Ham United        Tottenham
# 22         0            0 2022-04-24    West Ham United          Chelsea
# 23         0            1 2022-05-01    West Ham United          Arsenal
# 24         0            0 2022-05-15    West Ham United  Manchester City
#
#    result_x_x      new_team_x   date_y_x           team_y_x     opponent_y_x  \
# 0           W  Manchester Utd 2022-01-22  Manchester United         West Ham
# 1           L  Manchester Utd 2022-03-06  Manchester United  Manchester City
# 2           W  Manchester Utd 2022-03-12  Manchester United        Tottenham
# 3           D  Manchester Utd 2022-04-02  Manchester United   Leicester City
# 4           L  Manchester Utd 2022-04-19  Manchester United        Liverpool
# 5           L  Manchester Utd 2022-04-23  Manchester United          Arsenal
# 6           D  Manchester Utd 2022-04-28  Manchester United          Chelsea
# 7           W  Manchester Utd 2022-08-22  Manchester United        Liverpool
# 8           W  Manchester Utd 2022-09-04  Manchester United          Arsenal
# 9           L  Manchester Utd 2022-10-02  Manchester United  Manchester City
# 10          D  Manchester Utd 2022-10-16  Manchester United    Newcastle Utd
# 11          L  Manchester Utd 2022-11-06  Manchester United      Aston Villa
# 12          W  Manchester Utd 2023-01-14  Manchester United  Manchester City
# 13          L  Manchester Utd 2023-01-22  Manchester United          Arsenal
# 14          L  Manchester Utd 2023-03-05  Manchester United        Liverpool
# 15          L  Manchester Utd 2023-04-02  Manchester United    Newcastle Utd
# 16          W  Manchester Utd 2023-04-30  Manchester United      Aston Villa
# 17          L  Manchester Utd 2023-05-04  Manchester United         Brighton
# 18          L        West Ham 2022-01-22    West Ham United   Manchester Utd
# 19          D        West Ham 2022-02-13    West Ham United   Leicester City
# 20          L        West Ham 2022-03-05    West Ham United        Liverpool
# 21          L        West Ham 2022-03-20    West Ham United        Tottenham
# 22          L        West Ham 2022-04-24    West Ham United          Chelsea
# 23          L        West Ham 2022-05-01    West Ham United          Arsenal
# 24          D        West Ham 2022-05-15    West Ham United  Manchester City
#
#     ...    opponent_x_y result_x_y      new_team_y   date_y_y  \
# 0   ...  Manchester Utd          L        West Ham 2022-01-22
# 1   ...  Manchester Utd          W             NaN 2022-03-06
# 2   ...  Manchester Utd          L             NaN 2022-03-12
# 3   ...  Manchester Utd          D             NaN 2022-04-02
# 4   ...  Manchester Utd          W             NaN 2022-04-19
# 5   ...  Manchester Utd          W             NaN 2022-04-23
# 6   ...  Manchester Utd          D             NaN 2022-04-28
# 7   ...  Manchester Utd          L             NaN 2022-08-22
# 8   ...  Manchester Utd          L             NaN 2022-09-04
# 9   ...  Manchester Utd          W             NaN 2022-10-02
# 10  ...  Manchester Utd          D             NaN 2022-10-16
# 11  ...  Manchester Utd          W             NaN 2022-11-06
# 12  ...  Manchester Utd          L             NaN 2023-01-14
# 13  ...  Manchester Utd          W             NaN 2023-01-22
# 14  ...  Manchester Utd          W             NaN 2023-03-05
# 15  ...  Manchester Utd          W             NaN 2023-04-02
# 16  ...  Manchester Utd          L             NaN 2023-04-30
# 17  ...  Manchester Utd          W             NaN 2023-05-04
# 18  ...        West Ham          W  Manchester Utd 2022-01-22
# 19  ...        West Ham          D             NaN 2022-02-13
# 20  ...        West Ham          W             NaN 2022-03-05
# 21  ...        West Ham          W             NaN 2022-03-20
# 22  ...        West Ham          W             NaN 2022-04-24
# 23  ...        West Ham          W             NaN 2022-05-01
# 24  ...        West Ham          D             NaN 2022-05-15
#
#                     team_y_y    opponent_y_y  result_y_y  \
# 0            West Ham United  Manchester Utd           L
# 1            Manchester City  Manchester Utd           W
# 2          Tottenham Hotspur  Manchester Utd           L
# 3             Leicester City  Manchester Utd           D
# 4                  Liverpool  Manchester Utd           W
# 5                    Arsenal  Manchester Utd           W
# 6                    Chelsea  Manchester Utd           D
# 7                  Liverpool  Manchester Utd           L
# 8                    Arsenal  Manchester Utd           L
# 9            Manchester City  Manchester Utd           W
# 10          Newcastle United  Manchester Utd           D
# 11               Aston Villa  Manchester Utd           W
# 12           Manchester City  Manchester Utd           L
# 13                   Arsenal  Manchester Utd           W
# 14                 Liverpool  Manchester Utd           W
# 15          Newcastle United  Manchester Utd           W
# 16               Aston Villa  Manchester Utd           L
# 17  Brighton and Hove Albion  Manchester Utd           W
# 18         Manchester United        West Ham           W
# 19            Leicester City        West Ham           D
# 20                 Liverpool        West Ham           W
# 21         Tottenham Hotspur        West Ham           W
# 22                   Chelsea        West Ham           W
# 23                   Arsenal        West Ham           W
# 24           Manchester City        West Ham           D
#
#                       team_y      opponent_y result_y
# 0            West Ham United  Manchester Utd        L
# 1            Manchester City  Manchester Utd        W
# 2          Tottenham Hotspur  Manchester Utd        L
# 3             Leicester City  Manchester Utd        D
# 4                  Liverpool  Manchester Utd        W
# 5                    Arsenal  Manchester Utd        W
# 6                    Chelsea  Manchester Utd        D
# 7                  Liverpool  Manchester Utd        L
# 8                    Arsenal  Manchester Utd        L
# 9            Manchester City  Manchester Utd        W
# 10          Newcastle United  Manchester Utd        D
# 11               Aston Villa  Manchester Utd        W
# 12           Manchester City  Manchester Utd        L
# 13                   Arsenal  Manchester Utd        W
# 14                 Liverpool  Manchester Utd        W
# 15          Newcastle United  Manchester Utd        W
# 16               Aston Villa  Manchester Utd        L
# 17  Brighton and Hove Albion  Manchester Utd        W
# 18         Manchester United        West Ham        W
# 19            Leicester City        West Ham        D
# 20                 Liverpool        West Ham        W
# 21         Tottenham Hotspur        West Ham        W
# 22                   Chelsea        West Ham        W
# 23                   Arsenal        West Ham        W
# 24           Manchester City        West Ham        D
#
# [25 rows x 29 columns]

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# actual_x
# 0    9
# 1    3
# Name: count, dtype: int64
